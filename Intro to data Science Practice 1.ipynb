# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LILENDAR'

# %%
os.chdir('C:/Users/LILENDAR/Desktop/Python Directory')

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('Energy.xlsx')

# %%
data.head()
# Out:
#     Unnamed: 0 Energy Supply Energy Supply per capita  \
# 0          NaN    Petajoules               Gigajoules
# 1          NaN           NaN                      NaN
# 2  Afghanistan           321                       10
# 3      Albania           102                       35
# 4      Algeria          1959                       51
#
#   Renewable Electricity Production
# 0                                %
# 1                              NaN
# 2                          78.6693
# 3                              100
# 4                          0.55101

# %%
data['Energy Supp']=data['Energy Supply']*1000000

# %%
data
# Out:
#                     Unnamed: 0 Energy Supply Energy Supply per capita  \
# 0                          NaN    Petajoules               Gigajoules
# 1                          NaN           NaN                      NaN
# 2                  Afghanistan           321                       10
# 3                      Albania           102                       35
# 4                      Algeria          1959                       51
# ..                         ...           ...                      ...
# 224                   Viet Nam          2554                       28
# 225  Wallis and Futuna Islands             0                       26
# 226                      Yemen           344                       13
# 227                     Zambia           400                       26
# 228                   Zimbabwe           480                       32
#
#     Renewable Electricity Production  \
# 0                                  %
# 1                                NaN
# ...

# %%
# Out:
#                     Unnamed: 0 Energy Supply Energy Supply per capita  \
# 2                  Afghanistan           321                       10
# 3                      Albania           102                       35
# 4                      Algeria          1959                       51
# 6                      Andorra             9                      121
# 7                       Angola           642                       27
# ..                         ...           ...                      ...
# 224                   Viet Nam          2554                       28
# 225  Wallis and Futuna Islands             0                       26
# 226                      Yemen           344                       13
# 227                     Zambia           400                       26
# 228                   Zimbabwe           480                       32
#
#     Renewable Electricity Production Energy Supp
# 2                            78.6693   321000000
# ...

# %%
data2=data.drop('Energy Supply',axis=1)

# %%
data2.head()
# Out:
#     Unnamed: 0 Energy Supply per capita Renewable Electricity Production  \
# 0          NaN               Gigajoules                                %
# 1          NaN                      NaN                              NaN
# 2  Afghanistan                       10                          78.6693
# 3      Albania                       35                              100
# 4      Algeria                       51                          0.55101
#
#                                          Energy Supp
# 0  PetajoulesPetajoulesPetajoulesPetajoulesPetajo...
# 1                                                NaN
# 2                                          321000000
# 3                                          102000000
# 4                                         1959000000

# %%
data2.drop([0,1],axis=0)
# Out:
#                     Unnamed: 0 Energy Supply per capita  \
# 2                  Afghanistan                       10
# 3                      Albania                       35
# 4                      Algeria                       51
# 5               American Samoa                      NaN
# 6                      Andorra                      121
# ..                         ...                      ...
# 224                   Viet Nam                       28
# 225  Wallis and Futuna Islands                       26
# 226                      Yemen                       13
# 227                     Zambia                       26
# 228                   Zimbabwe                       32
#
#     Renewable Electricity Production Energy Supp
# 2                            78.6693   321000000
# 3                                100   102000000
# 4                            0.55101  1959000000
# 5                           0.641026         NaN
# ...

# %%
energy=data2

# %%
energy['Country']=energy['Unnamed: 0']

# %%
energy.head()
energy=energy.drop([0,1],axis=0)

# %%
energy.head()
#energy=energy.drop('Unnamed: 0',axis=1)
energy= energy.set_index('Country')

# %%
gdp=pd.read_excel('gdp.xls')

# %%
gdp.head()
gdp=gdp.drop([0,1],axis=0)

# %%
gdp.head()
# Out:
#     Data Source World Development Indicators         Unnamed: 2  \
# 2  Country Name                 Country Code     Indicator Name
# 3         Aruba                          ABW  GDP (current US$)
# 4   Afghanistan                          AFG  GDP (current US$)
# 5        Angola                          AGO  GDP (current US$)
# 6       Albania                          ALB  GDP (current US$)
#
#        Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# 2  Indicator Code  2.006000e+03  2.007000e+03  2.008000e+03  2.009000e+03
# 3  NY.GDP.MKTP.CD  2.424581e+09  2.615084e+09  2.745251e+09  2.498883e+09
# 4  NY.GDP.MKTP.CD  6.971286e+09  9.747880e+09  1.010923e+10  1.243909e+10
# 5  NY.GDP.MKTP.CD  5.238101e+10  6.526645e+10  8.853861e+10  7.030716e+10
# 6  NY.GDP.MKTP.CD  8.896074e+09  1.067732e+10  1.288135e+10  1.204422e+10
#
#      Unnamed: 8    Unnamed: 9   Unnamed: 10   Unnamed: 11   Unnamed: 12  \
# ...

# %%
gdp=gdp.set_index(['Data Source'])

# %%
#gdp=gdp.set_column(['Country Name'])
gdp.head()
gdpp=gdp.drop(['World Development Indicators','Unnamed: 2','Unnamed: 3'],axis=1)
gdpp.head()
#gdpp.iloc(0)
# Out:
#                 Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# Data Source
# Country Name  2.006000e+03  2.007000e+03  2.008000e+03  2.009000e+03
# Aruba         2.424581e+09  2.615084e+09  2.745251e+09  2.498883e+09
# Afghanistan   6.971286e+09  9.747880e+09  1.010923e+10  1.243909e+10
# Angola        5.238101e+10  6.526645e+10  8.853861e+10  7.030716e+10
# Albania       8.896074e+09  1.067732e+10  1.288135e+10  1.204422e+10
#
#                 Unnamed: 8    Unnamed: 9   Unnamed: 10   Unnamed: 11  \
# Data Source
# Country Name  2.010000e+03  2.011000e+03  2.012000e+03  2.013000e+03
# Aruba         2.390503e+09  2.549721e+09  2.534637e+09  2.701676e+09
# Afghanistan   1.585657e+10  1.780429e+10  2.000160e+10  2.056107e+10
# Angola        8.379950e+10  1.117897e+11  1.280529e+11  1.367099e+11
# Albania       1.192693e+10  1.289077e+10  1.231983e+10  1.277622e+10
#
#                Unnamed: 12   Unnamed: 13
# Data Source
# Country Name  2.014000e+03  2.015000e+03
# ...

# %%
header_row = 0

gdpp.columns = gdpp.iloc[header_row]
gdpp
# Out:
# Country Name        2006.0        2007.0        2008.0        2009.0  \
# Data Source
# Country Name  2.006000e+03  2.007000e+03  2.008000e+03  2.009000e+03
# Aruba         2.424581e+09  2.615084e+09  2.745251e+09  2.498883e+09
# Afghanistan   6.971286e+09  9.747880e+09  1.010923e+10  1.243909e+10
# Angola        5.238101e+10  6.526645e+10  8.853861e+10  7.030716e+10
# Albania       8.896074e+09  1.067732e+10  1.288135e+10  1.204422e+10
# ...                    ...           ...           ...           ...
# Kosovo        3.846820e+09  4.655899e+09  5.687418e+09  5.653793e+09
# Yemen, Rep.   1.906198e+10  2.165053e+10  2.691085e+10  2.513027e+10
# South Africa  2.716385e+11  2.994155e+11  2.867698e+11  2.959365e+11
# Zambia        1.275686e+10  1.405696e+10  1.791086e+10  1.532834e+10
# Zimbabwe      5.443896e+09  5.291950e+09  4.415703e+09  9.665793e+09
#
# Country Name        2010.0        2011.0        2012.0        2013.0  \
# Data Source
# ...

# %%
#a=gdpp.iloc[0]
#gdpp.drop(['Country Name'],axis=0)
gdpp.index
# Out:
# Index(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra', 'Arab World',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Data Source', length=264)

# %%
scimen=pd.read_excel('ScimEn.xlsx')

# %%
scimen.head()
# Out:
#    Rank         Country            Region  Documents  Citable documents  \
# 0     1           China    Asiatic Region     235126             233883
# 1     2   United States  Northern America     157811             154288
# 2     3           Japan    Asiatic Region      46032              45559
# 3     4           India    Asiatic Region      39893              38848
# 4     5  United Kingdom    Western Europe      38873              37780
#
#    Citations  Self-citations  Citations per document  H index
# 0    1909601         1306438                    8.12      224
# 1    1940563          639345                   12.30      333
# 2     436961          109968                    9.49      181
# 3     368175          123446                    9.23      171
# 4     536378          100038                   13.80      208

# %%
data2=scimen[0:15]
data2.head()
# Out:
#    Rank         Country            Region  Documents  Citable documents  \
# 0     1           China    Asiatic Region     235126             233883
# 1     2   United States  Northern America     157811             154288
# 2     3           Japan    Asiatic Region      46032              45559
# 3     4           India    Asiatic Region      39893              38848
# 4     5  United Kingdom    Western Europe      38873              37780
#
#    Citations  Self-citations  Citations per document  H index
# 0    1909601         1306438                    8.12      224
# 1    1940563          639345                   12.30      333
# 2     436961          109968                    9.49      181
# 3     368175          123446                    9.23      171
# 4     536378          100038                   13.80      208

# %%
#data2=data2.set_index('Country')
#data2=data2.drop('Region',axis=1)
data2.shape
# Out:
# (15, 7)

# %%
gdpp.shape
# Out:
# (264, 10)

# %%
energy.shape
# Out:
# (227, 3)

# %%
data3=pd.merge(data2, gdpp, how='left', left_index=True, right_index=True)

# %%
data4=pd.merge(data3, energy, how='left', left_index=True, right_index=True)

# %%
data4.shape
# Out:
# (15, 20)

# %%
def answer_one():
    
    return data4
