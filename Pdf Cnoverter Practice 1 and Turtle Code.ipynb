# %%
data2.head(10)
# Out:
#     SL                                       D escription     Budget  \
# 0   No                                                NaN  estimates
# 1  NaN                                                NaN  2019-2020
# 2  NaN                                                NaN        NaN
# 3  NaN                                                NaN        NaN
# 4    1                                   REVENUE RECEIPTS  178697.42
# 5  NaN  a) Tax Revenue (i + ii + iii + iv + v + vi + vii)  110271.18
# 6  NaN                           i) Goods and Service Tax   36485.62
# 7  NaN                   ii) Stamps and registration Fees    6600.00
# 8  NaN                                  iii) Land Revenue     300.00
# 9  NaN                                     iv)  Sales Tax   28000.00
#
#   Actuals upto         % of Actuals to Budget
# 0          DEC                      Estimates
# 1          NaN                  Corresponding
# 2         2019  Current previous year 2019-20
# ...

# %%
data1.shape
# Out:
# (53, 5)

# %%
data3=pd.concat([data1.iloc[:,3],data2.iloc[:,3]],axis=1)
data3
# Out:
#       Unnamed: 3 Actuals upto
# 0            NaN          DEC
# 1   Actuals upto          NaN
# 2       NOVEMBER         2019
# 3            NaN          NaN
# 4           2019     72322.49
# 5            NaN     57161.00
# 6            NaN     19133.41
# 7       63750.41      4047.37
# 8       51302.70        15.43
# 9       16786.82     14627.53
# 10       3636.89      3526.37
# 11         14.99     13120.67
# 12      13748.77      2690.22
# 13       3341.15      2173.52
# 14  ($) 11314.52     12987.97
# 15       2459.56     40456.36
# 16       1936.11        46.34
# 17      10511.60         0.00
# 18      35039.59     40410.02
# 19         43.30    112778.85
# 20          0.00    101729.87
# 21      34996.29          NaN
# 22      98790.00     44909.91
# 23      88891.71          NaN
# 24           NaN     10778.71
# 25      39465.91     26247.26
# 26           NaN     12753.98
# 27       9656.51      7040.01
# 28      23496.06      5805.24
# 29      11414.61     5364. 65
# ...

# %%
df_output = pd.concat([data1["Unnamed: 3"],data2["Actuals upto"]])
print(df_output)
df_output.to_excel("output2.xlsx")

# %%
type(data2)

# %%
data2=data2.values
type(data2)

# %%
data2[:,3]

# %%
data1=data1.values
type(data1)

# %%
data1[:,3]

# %%
data3=data1[:,3]+data2[:,3]

# %%
data=data.values
print(data[:,4])

# %%
print(df_first_shift['Product'])

df_all = pd.concat([df_first_shift, df_second_shift, df_third_shift])
print(df_all)

pivot = df_all.groupby(['Shift']).mean()
shift_productivity = pivot.loc[:,"Production Run Time (Min)":"Products Produced (Units)"]

print(shift_productivity)

#shift_productivity.plot(kind='bar')
#plt.show()

df_all.to_excel("output.xlsx")

# %%
fruit="banana"
index=0
while index<len(fruit):
    print(index,fruit[index])
    index+=1

# %%
for letter in fruit:
    print(letter)

# %%
count=0
fruit="A DataFrame with mixed type columns(e.g., str/object, int64, float32) results in an ndarray of the broadest type that accommodates these mixed types"
for letter in fruit:
    if letter=="a" or letter=="A":
        count+=1
print(count)

# %%
word="jack fruit"

if word=="banana":
    print("yes it is banana")
elif word< "banana":
    print("your",word,"comes before banana in dictionary")
elif word > "banana":
    print("your",word,"comes after banana in dictionary")
else:
    print("its banana")

# %% [markdown]
# lame="Hello"
# dir(lame)
# print(lame.lower())

# %% [markdown]
# # dir(lame)

# %%
import turtle

# %%
win=turtle.Screen()

# %%
win.bgcolor("lightgreen")
a=turtle.Turtle()

a.speed(4)
a.shape("turtle")
a.color("red")

i=100
dist=5
for j in range(10):
    #a.stamp()
    
    a.forward(i)
    a.left(90)
    a.forward(i)
    a.left(90)
    a.forward(i)
    a.left(90)
    a.forward(i+10)
win.exitonclick()
