# %%
import os
os.chdir("C:/Users/LILENDAR/Desktop/Python Directory")

# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

names_ids = df.index.str.split('\s\(') # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df = df.drop('Totals')
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %%
df.head(15)
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
# Australia          25   139     152     177    468        18       5
# Austria            26    18      33      35     86        22      59
# Azerbaijan          5     6       5      15     26         5       0
# Bahamas            15     5       2       5     12         0       0
# Bahrain             8     0       0       1      1         0       0
# Barbados           11     0       0       1      1         0       0
# Belarus             5    12      24      39     75         6       6
# Belgium            25    37      52      53    142        20       1
# ...

# %%
def answer_one():
    only_gold=df[(df['Gold']>0)&(df['Gold.1']>0)]
    only_gold['Difference']=(abs(only_gold['Gold']-only_gold['Gold.1']))/only_gold['Gold.2']
    return only_gold['Difference'].idxmax()
answer_one()
# Out:
# C:\Users\LILENDAR\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 'Bulgaria'

# %%
def answer():
    df['Points']=df['Gold.2']*3+df['Silver.2']*2+df['Bronze.2']*1
    return df['Points']
answer()
# Out:
# Afghanistan                           2
# Algeria                              27
# Argentina                           130
# Armenia                              16
# Australasia                          22
#                                    ...
# Yugoslavia                          171
# Independent Olympic Participants      4
# Zambia                                3
# Zimbabwe                             18
# Mixed team                           38
# Name: Points, Length: 146, dtype: int64

# %%
def answer_three():
    k=[]
    data1=df[(df['Gold']>1)&(df['Gold.1']>1)]

    for i in range(len(data1["Gold"])):

    
        diff=data1["Gold"][i]-data1["Gold.1"][i]
        summ=data1["Gold"][i]+data1["Gold.1"][i]
        p=abs(diff/summ)
        k.append(p)
        
    country=data1.index[k.index(max(k))]
    return country

# %%
answer_three()
# Out:
# 'Australia'

# %%
census_df = pd.read_csv('census.csv')
census_df.head(30)
# Out:
#     SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME           CTYNAME  \
# 0       40       3         6      1       0  Alabama           Alabama
# 1       50       3         6      1       1  Alabama    Autauga County
# 2       50       3         6      1       3  Alabama    Baldwin County
# 3       50       3         6      1       5  Alabama    Barbour County
# 4       50       3         6      1       7  Alabama       Bibb County
# 5       50       3         6      1       9  Alabama     Blount County
# 6       50       3         6      1      11  Alabama    Bullock County
# 7       50       3         6      1      13  Alabama     Butler County
# 8       50       3         6      1      15  Alabama    Calhoun County
# 9       50       3         6      1      17  Alabama   Chambers County
# 10      50       3         6      1      19  Alabama   Cherokee County
# 11      50       3         6      1      21  Alabama    Chilton County
# ...

# %%
def answer_six(): 
    df1=census_df.sort_values(['STNAME','POPESTIMATE2015'], ascending=False).groupby('STNAME').head(3).copy()
    df2=df1.reset_index().groupby('STNAME').sum().sort_values(['POPESTIMATE2015'], ascending=False).head(3).copy()
    return list(df2.index)
answer_six()
# Out:
# ['California', 'Texas', 'Florida']

# %%
def answer_seven():
    df=census_df[census_df['SUMLEV']==50]
    df['STDEV']=df[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013',
                'POPESTIMATE2014','POPESTIMATE2015']].std(axis=1)
    return df.loc[df['STDEV'].idxmax()]['CTYNAME']
answer_seven()
# Out:
# C:\Users\LILENDAR\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 'Harris County'

# %%
def answer_eight():
    df=census_df[census_df['SUMLEV']==50]
    region1=df['REGION']==1
    region2=df['REGION']==2
    country_name=df['CTYNAME'].str.startswith('Washington')
    population=df['POPESTIMATE2015']>df['POPESTIMATE2014']
    df=df[(region1|region2)&country_name&population]
    return df[['STNAME','CTYNAME']]
answer_eight()
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County

# %%
max_county=census_df.loc[census_df["COUNTY"].idxmax()]["STNAME"]
# Out:
# 'Virginia'

# %%
a=[x for x in census_df["STNAME"]]

# %%
a=[x for x in census_df["STNAME"]]
b=set(a)
c=list(b)
# Out:
# ['South Carolina',
#  'Nevada',
#  'New York',
#  'New Hampshire',
#  'Vermont',
#  'Maryland',
#  'Colorado',
#  'Pennsylvania',
#  'Illinois',
#  'Rhode Island',
#  'New Mexico',
#  'North Carolina',
#  'Texas',
#  'Delaware',
#  'California',
#  'North Dakota',
#  'Oregon',
#  'Hawaii',
#  'District of Columbia',
#  'Alabama',
#  'Virginia',
#  'Alaska',
#  'New Jersey',
#  'Maine',
#  'Kansas',
#  'Utah',
#  'Kentucky',
#  'Washington',
#  'Georgia',
#  'Mississippi',
#  'Oklahoma',
#  'Missouri',
#  'Minnesota',
#  'West Virginia',
#  'Montana',
#  'Tennessee',
#  'Connecticut',
#  'Arkansas',
#  'Wisconsin',
#  'Wyoming',
#  'Indiana',
#  'Ohio',
#  'Louisiana',
#  'Arizona',
#  'Iowa',
#  'Massachusetts',
#  'Idaho',
#  'Nebraska',
#  'South Dakota',
#  'Michigan',
#  'Florida']

# %%
from collections import Counter 
  
# driver program
m=[]
for x in c:
    d = Counter(census_df["STNAME"]) 
    print('{} has occurred {} times'.format(x, d[x]))
    m.append(d[x])
max(m)
# Out:
# South Carolina has occurred 47 times
# Nevada has occurred 18 times
# New York has occurred 63 times
# New Hampshire has occurred 11 times
# Vermont has occurred 15 times
# Maryland has occurred 25 times
# Colorado has occurred 65 times
# Pennsylvania has occurred 68 times
# Illinois has occurred 103 times
# Rhode Island has occurred 6 times
# New Mexico has occurred 34 times
# North Carolina has occurred 101 times
# Texas has occurred 255 times
# Delaware has occurred 4 times
# California has occurred 59 times
# North Dakota has occurred 54 times
# Oregon has occurred 37 times
# Hawaii has occurred 6 times
# District of Columbia has occurred 2 times
# Alabama has occurred 68 times
# Virginia has occurred 134 times
# Alaska has occurred 30 times
# New Jersey has occurred 22 times
# Maine has occurred 17 times
# Kansas has occurred 106 times
# Utah has occurred 30 times
# Kentucky has occurred 121 times
# Washington has occurred 40 times
# Georgia has occurred 160 times
# ...

# %%
max(census_df["SUMLEV"])
# Out:
# 50

# %%
census_df["COUNTY"][2990:3010]
# Out:
# 2990    750
# 2991    760
# 2992    770
# 2993    775
# 2994    790
# 2995    800
# 2996    810
# 2997    820
# 2998    830
# 2999    840
# 3000      0
# 3001      1
# 3002      3
# 3003      5
# 3004      7
# 3005      9
# 3006     11
# 3007     13
# 3008     15
# 3009     17
# Name: COUNTY, dtype: int64

# %%
def answer_five():
    df=census_df[census_df['SUMLEV']==50]
    df=df.groupby(['SUMLEV','STNAME']).size().to_frame(name='count').reset_index()
    print(df)
    return df.loc[df['count'].idxmax()]['STNAME']
answer_five()
# Out:
#     SUMLEV                STNAME  count
# 0       50               Alabama     67
# 1       50                Alaska     29
# 2       50               Arizona     15
# 3       50              Arkansas     75
# 4       50            California     58
# 5       50              Colorado     64
# 6       50           Connecticut      8
# 7       50              Delaware      3
# 8       50  District of Columbia      1
# 9       50               Florida     67
# 10      50               Georgia    159
# 11      50                Hawaii      5
# 12      50                 Idaho     44
# 13      50              Illinois    102
# 14      50               Indiana     92
# 15      50                  Iowa     99
# 16      50                Kansas    105
# 17      50              Kentucky    120
# 18      50             Louisiana     64
# 19      50                 Maine     16
# 20      50              Maryland     24
# 21      50         Massachusetts     14
# ...

# %% [markdown]
# # class and inheritance

# %%
class weight:
    
    def __init__(self,x,y):
        
        self.father=x
        self.mother=y
        
        year2010=weight(60,50)
        year2015=weight(61,51)
        year2020=weight(63,52)
        
        def family_wt(self):
            return self.father+self.mother
        print(year2015.family_wt())
